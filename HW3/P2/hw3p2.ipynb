# %%
import numpy as np
import torch
import torch.nn.functional as F
from torch import nn
from torch.nn.utils.rnn import *
from phoneme_list import *
from torch.utils import data
from ctcdecode import CTCBeamDecoder
import Levenshtein
from Levenshtein import distance
train_data = np.load('train.npy', allow_pickle=True)
train_labels = np.load('train_labels.npy', allow_pickle=True)
cuda = True

device = torch.device("cuda:0" if cuda else "cpu")

dev_data = np.load('dev.npy', allow_pickle=True)
dev_labels = np.load('dev_labels.npy', allow_pickle=True)

# %%
class MyDataset(data.Dataset):
    def __init__(self, X, Y):
        self.X = X
        self.Y = Y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, index):
        X = self.X[index]
        Y = self.Y[index] + 1
        return torch.from_numpy(X).float(), X.shape[0], torch.from_numpy(Y).long(), Y.shape[0]

# %%
num_workers = 8 if cuda else 0
batch_size = 64

# %%
def collate(sequences):
    X_list, X_shapes, Y_list, Y_shapes = zip(*sequences)
    return pad_sequence(X_list, batch_first=True), torch.Tensor(np.asarray(X_shapes)), pad_sequence(Y_list, batch_first=True), torch.tensor(np.asarray(Y_shapes))

# %%
train_dataset = MyDataset(train_data, train_labels)

train_loader_args = dict(shuffle=True, batch_size=batch_size, num_workers=num_workers, pin_memory=True,
                         collate_fn=collate) if cuda else dict(shuffle=True, batch_size=64, collate_fn=collate)


train_loader = data.DataLoader(train_dataset, **train_loader_args)

# %%
class Model(nn.Module):
    def __init__(self, out_vocab, input_feature_size):
        super(Model, self).__init__()

        self.lstm = nn.LSTM(input_feature_size, 256, bidirectional=True,
                            batch_first=True, num_layers=4, dropout=0.3)
        self.output1 = nn.Linear(512, 256)
        self.output2 = nn.Linear(256, out_vocab)

    def forward(self, X, lengths):

        packed_X = pack_padded_sequence(X, lengths, enforce_sorted=False, batch_first=True)
        packed_out = self.lstm(packed_X)[0]

        out, out_lens = pad_packed_sequence(packed_out, batch_first=True)
        
        out = self.output1(out)
        out = self.output2(out)
        out = out.log_softmax(2)
        return out, out_lens

# %%
model = Model(len(PHONEME_LIST), len(train_dataset[0][0][0]))
model.to(device)
# Out:
# Model(
#   (lstm): LSTM(13, 256, num_layers=4, batch_first=True, dropout=0.3, bidirectional=True)
#   (output1): Linear(in_features=512, out_features=256, bias=True)
#   (output2): Linear(in_features=256, out_features=42, bias=True)
# )

# %%
criterion = nn.CTCLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=5e-6)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=0, min_lr=1e-4, verbose=True)

# %%
dev_dataset = MyDataset(dev_data, dev_labels)

dev_loader_args = dict(shuffle=False, batch_size=batch_size, num_workers=num_workers, pin_memory=True,
                       collate_fn=collate) if cuda else dict(shuffle=False, batch_size=64, collate_fn=collate)
dev_loader = data.DataLoader(dev_dataset, **dev_loader_args)

# %%
decoder = CTCBeamDecoder(PHONEME_MAP, beam_width=20, num_processes=8,
                         blank_id=0, log_probs_input=True)

# %%
def seq2phoneme(sequence, seq_len):
    result = ''
    if isinstance(seq_len, torch.Tensor):
        seq_len = seq_len.item()
    for i in range(seq_len):
        result += PHONEME_MAP[sequence[i]]
    return result

# %%
print(len(train_loader))
for epoch in range(30):
    model.train()
    count = 0
    avg_train_loss = 0
    for (X, X_lens, Y, Y_lens) in train_loader:
        optimizer.zero_grad()

        X = X.to(device)
        X_lens = X_lens.to(device)
        Y = Y.to(device)
        Y_lens = Y_lens.to(device)
        count += 1
        out, out_lens = model(X, X_lens)
        out = out.permute(1,0,2)
        loss = criterion(out, Y, out_lens, Y_lens)
        if count % 100 == 0:
            print("AVG_loss", count, 'loss=%f' % (avg_train_loss/100))
            avg_train_loss = 0
        else:
            avg_train_loss += float(loss)
        
        loss.backward()
        optimizer.step()
        torch.cuda.empty_cache()
        del X
        del X_lens
        del Y
        del Y_lens
        del loss
        
        
    with torch.no_grad():
        model.eval()
        total_dist = []
        loss = None
        for (test_X, test_X_lens, test_Y, test_Y_lens) in dev_loader:

            test_X = test_X.to(device)
            test_X_lens = test_X_lens.to(device)
            test_Y = test_Y.to(device)
            test_Y_lens = test_Y_lens.to(device)

            out, out_lens = model(test_X, test_X_lens)
            out = out.permute(1,0,2)
            if loss is None:
                loss = float(criterion(out, test_Y, out_lens, test_Y_lens))
            else:
                loss += float(criterion(out, test_Y, out_lens, test_Y_lens))
            out = out.permute(1, 0, 2)
            
            
            Y_hat, _, _, Y_hat_lens = decoder.decode(out, out_lens)
            assert(len(Y_hat) == len(test_Y))
            val_seq_array = []
            for i in range(len(Y_hat)):
                val_seq_array.append(
                    (seq2phoneme(Y_hat[i][0], Y_hat_lens[i][0]), seq2phoneme(test_Y[i], test_Y_lens[i])))

            for ex in val_seq_array:
                if val_seq_array.index(ex) % 100 == 0:
                    if epoch % 3 == 0:
                total_dist.append(distance(ex[0], ex[1]))
            torch.cuda.empty_cache()
            del test_X
            del test_X_lens
            del test_Y
            del test_Y_lens
            
        print("Average Lev Distance", epoch, np.mean(total_dist))
        print("AVG VAL LOSS PER BATCH", loss/len(dev_loader))
        scheduler.step(loss/len(dev_loader))
    if (epoch > 9) and (epoch % 3 == 0 or epoch == 29):
        checkpoint = {'epoch': epoch, "model": model.state_dict(
        ), 'optimizer': optimizer.state_dict(), 'loss': criterion, 'scheduler': scheduler.state_dict()}
        torch.save(checkpoint, "checkpointLAST_%d.pth" % (epoch))
# Out:
# 344
# AVG_loss 100 loss=4.279128
# AVG_loss 200 loss=3.383192
# AVG_loss 300 loss=3.386090
# h
# .mistrkWiltrizDIhpashlhvDhmidhlklAshz.hndWIrglAdtUWelkhmHizgasphl.
# 65
# h
# .hWEvhvdispeROldwtfrm!.bRyhnsenstit.AndnUDhfifTpYnt.WhzHiz.
# 58
# h
# .onDhlAsAtidEinEpRhl.DhnU?oRktymzphbliSthnhkwnthvDhstRyk.kamplhkEShnz.WicWrdilEiNAlhgzAndrznUjrzIbRij.hndstEtidDAtDIenjhniRHimselfWhzintwn.AndAtHizofhsonWest.tenTstRIt.
# 167
# h
# .tUmIt.WhztUfyndIchDr.
# 21
# h
# .veRIhsdiSizrfRIkWhntlIoRnhmentid.hndgaRniSt.WiDitsgREsfhlIvz.hndDIzrshmtymzbYldinsUps.olDOitizmoR?UZhlIkhnfyndiniNgliSkukrI.tUDhmAkrhlsosAzHIRgivhn.
# 148
# h
# .DIzprshnzDen.displEdtoRdzIchDr.pRisyslIDhsEmp?URIljelhsIz.WicAnhmEtDhmenhvdimakRhsIz.DhsEm.IgrnhsthsnAcDhsmolhsthdvAntijiz.WicDeR.IkWhlzkhntesthd.AndDhsEmdizyrthprEdasthntEShslI.DOzhvWicDEWrinphzeShn.
# 200
# h
# .HIgEvTANksfoRaRfUdhndkhmfrt.hndpREdfrDhpURAndesthtUtingREtsitIz.HWeRDhstRhghlfrlyfWhzHaRdrDhnitWhzHIRWiThs.
# 107
# h
# .duRiNDIakShnHIWenthbwtWiDHizHedwnhndnevrliftidHizyz.
# 52
# h
# .ingudfETHwevr.HIiznatshfiShntlIimAjhnhtiv.thflAtrHimselfWiTDhslythstHOphvDiskynd.
# 81
# h
# .itWhzhndrshcaspiShsrkhmstAnsizDAtSIstaRthdwtDismoRniNthlukfrWrk.
# 64
# h
# .HItRhbhldOvrmenIlithldItElz.AndtoktprfhNktRhlIthevRIbadI.
# 57
# h
# .DhHOlTiNWhzhtRyfhlad.
# 21
# h
# .Azitiz.hnlesyAmistEkhn.shmhvDhRendiN.WhlbIan.aRsyd.AndDEnOit.
# 61
# h
# .HIsmyldgilthlIezHIAdhd.bhtymhsthdmityWhzmoRDhnhlithlkhnsrndmyself.
# 66
# h
# .ykAnatHOpDhtDIzpEjizWhlbIolthgeDrfRIfrmhnAkRhnizhmzAndeRrz.
# 59
# h
# .ytuk.kWythfAnsItUHim.Wy.
# 24
# h
# .Dhneksminht.SIWhzinDislEdIzaRmz.
# 32
# h
# .misWudlIdidnatRekhlektHrselfsO.bhtWhzsOinRIAlhtI.inHrpIshndceRitIWrinstiNktivrcUz.AkshdhntkudnatinkRIsDem.
# 106
# h
# .klodIhWudnatan.enIhkwnt.hlwHimtUhkhmphnIHr.AndTANkiNHimfrHiz.ofrzezWelezSIkud.tuklIvhvHimintiRz.
# 96
# h
# .?UdOntmIntisEHIzgOiNtiflagkrklhnd.
# 34
# h
# .AndDIinkhnsisthntWumhnfelhpanHizbhthnIbRestWIpiNkOp?hslI.
# 57
# h
# .DEHeldkhnvenikhlzinDIOphnfIldz.And.bIiNtRItidWiTgREtvyhlhnsAndkRUltIbyDhskatiSghvrmhnt.moRDhnWhnstukaRmzdriNDOzREnz.
# 116
# h
# .RIinkaRnEShnhndDhkanvrshvspiRits.
# 33
# h
# .yluktAtitpRitIklOs.hndysedgREt.gad.
# 35
# h
# .DisOphniNluktfr.olDhWrld.lykhmwThvHel.inDhWrdzhvDI.ytinrhntp?uRhthnpRIcrz.HUtrndhWEfrmitWiTHoRr.
# 96
# h
# .ykudnatHelpsmyliNtisIimluksObiganHizlithlHoRs.HizloNlegznwhndDenthciNDhgRwndmEdHimluklykhsiksfutidsentoR.
# 105
# h
# .bhtHIluktbAkAtcaRhlsthn.DhgEDhvalhthlhndDhb?Uthfhl.WiTRIlhfekShn.
# 65
# h
# .WiThSwt.DhbYzdAStpelmelthmItDhpAktREn.AndfaliNinbiHyndDhslOmUviNbrOz.rjdDhmon.WiTdrisivSwtshndshndRIRIswndiNslApsonDhAnhmhlzflANks.
# 131
# h
# .Wynathlw?oRsilvrthftsthlhgZrIht.inhnAcrhlmAnr.
# 46
# h
# .bhtHIRDIOnlITiNDhthkrdthHrWhzthstaphndlukinWhnhvDhSapstilHISudAskHrWhtSIWhzlukiNAt.
# 83
# h
# .HIRAzWelezinhnhmbrhvhDrplEshz.WhnkhnWelhpRISIEtDhkhlOkWIhldefhniShnhvkAbrE.
# 75
# h
# .mykelis.DhtikhthvlIvhpashl.smyldvEglIWiDHizglUdlips.HizpEstImUnfEsdRUpt.hndrDhWEthvmelhnkalIhsent.
# 98
# h
# .AndSIsoDIhDrbrdzHapiNhbwtAndtWitriNHelplhslI.
# 45
# h
# .myfRend.WiTmenIhDrz.WhzbIiNkeRIdwt.thdyelsWeR.
# 56
# .HIgEvTANksfofUdindkhmfrt.DhmpREdfrmDhpURindhstitUtingREtsitIz.WiDhstRughlfrlyHWhzHaRtrDhnOWhzHIRWiThst.
# .HIgEvTANksfoRaRfUdhndkhmfrt.hndpREdfrDhpURAndesthtUtingREtsitIz.HWeRDhstRhghlfrlyfWhzHaRdrDhnitWhzHIRWiThs.
# 20
# .driN?akShnHIWhnthbwtWitHizHAddwnnevrliftidHizyz.
# .duRiNDIakShnHIWenthbwtWiDHizHedwnhndnevrliftidHizyz.
# 11
# .AndgudfEtHwevr.HiznatshfiShtlIhmAjhnhtU.tiflAtrHimselfWiTislytizHOphDHiskynd.
# .ingudfETHwevr.HIiznatshfiShntlIimAjhnhtiv.thflAtrHimselfWiTDhslythstHOphvDiskynd.
# 16
# .itWhzhnrshchspiShsrkhmstAnsezDAtSIztathdwtDismaniNthlhkfrWrk.
# .itWhzhndrshcaspiShsrkhmstAnsizDAtSIstaRthdwtDismoRniNthlukfrWrk.
# 8
# .HIjRAbhldhvrmenIlhbhldItelhv.OnklaktprfhmtoRlIthevIbatI.
# .HItRhbhldOvrmenIlithldItElz.AndtoktprfhNktRhlIthevRIbadI.
# 18
# .DhvOTiNWhzhtRyfhlhd.
# .DhHOlTiNWhzhtRyfhlad.
# 3
# .Azitiz.DhnlhsyhmhstEkhn.shmhvDhRenIiN.WhlbIan.aRsyd.AndDEnOit.
# .Azitiz.hnlesyAmistEkhn.shmhvDhRendiN.WhlbIan.aRsyd.AndDEnOit.
# 5
# .HIsmyldgilthlIezIedid.bhdymhsthdmRdyWhzmoRDhnhlithlkhnsrndmyself.
# .HIsmyldgilthlIezHIAdhd.bhtymhsthdmityWhzmoRDhnhlithlkhnsrndmyself.
# 6
# .ykAnAtHOlptDhtDIzpEjhzWhDIolthgeDrfRIfrlhnakrnizhnzAndeRrtz.
# .ykAnatHOpDhtDIzpEjizWhlbIolthgeDrfRIfrmhnAkRhnizhmzAndeRrz.
# 12
# .ytukkWythfensitUHim.Wy.
# .ytuk.kWythfAnsItUHim.Wy.
# 3
# .Dhteksminit.SIWhzinDislIzaRmz.
# .Dhneksminht.SIWhzinDislEdIzaRmz.
# 4
# .misWhtlIdidnatRekhlhktHrselfsO.bhtWhzsOiNRIAlhtI.inHarpEshndceRhtIWrinstiNtivrcUz.AkshdenskudnatinkRIsDem.
# .misWudlIdidnatRekhlektHrselfsO.bhtWhzsOinRIAlhtI.inHrpIshndceRitIWrinstiNktivrcUz.AkshdhntkudnatinkRIsDem.
# 10
# .kladIhWudnatanenIhkwnt.hlwHimtUhkhphnIr.AndTiNkiNHimfrHiz.afrsizWelhzSIkUhd.tuklIvhvHivintirz.
# .klodIhWudnatan.enIhkwnt.hlwHimtUhkhmphnIHr.AndTANkiNHimfrHiz.ofrzezWelezSIkud.tuklIvhvHimintiRz.
# 13
# .?UdOmIndisEHIzdYnthflodkiklhn.
# .?UdOntmIntisEHIzgOiNtiflagkrklhnd.
# 12
# .hndDIinkhnsisthnoRmhnfelhpanHizbhtmIbRestWIpiNkOpIhslE.
# .AndDIinkhnsisthntWumhnfelhpanHizbhthnIbRestWIpiNkOp?hslI.
# 8
# .DEHwlhkhnbenth.OlshndIOkhnfIldz.And.IiNtRItidWiTgREtfylhntsinkUtIWytitskatiskhvritz.WrDhnWhnsthkaRnstriNOsREnz.
# .HIgEvTANksfoRaRfUdhndkhmfrt.hndpREdfrDhpURAndesthtUtingREtsitIz.HWeRDhstRhghlfrlyfWhzHaRdrDhnitWhzHIRWiThs.
# 16
# .driN?okShnHIWenthbwtWidHizHeddwnnevrleftidHizyz.
# .duRiNDIakShnHIWenthbwtWiDHizHedwnhndnevrliftidHizyz.
# 11
# .AndgudfEtHwevr.HIHUznatshfiShntmImAjhnhti.thflAtrHimselfWiTislythstHOphvDiskynd.
# .ingudfETHwevr.HIiznatshfiShntlIimAjhnhtiv.thflAtrHimselfWiTDhslythstHOphvDiskynd.
# 10
# .itWhzhndrshcaspiShsTrkhmztAnsizDAtSIztytidwtDismoRniNthlhkfrWrk.
# .itWhzhndrshcaspiShsrkhmstAnsizDAtSIstaRthdwtDismoRniNthlukfrWrk.
# 7
# .HIcRAbhldhvrmenIlithldItelT.AndplaptpRrfhmtoRlIthevIbadI.
# .HItRhbhldOvrmenIlithldItElz.AndtoktprfhNktRhlIthevRIbadI.
# 15
# .DhvOTiNWhzhtRyfhlad.
# .DhHOlTiNWhzhtRyfhlad.
# 2
# .Azitiz.DhndlesyhmhstEkhn.shmhvDhReniN.WhlbIon.aRsyd.AndDEnOit.
# .Azitiz.hnlesyAmistEkhn.shmhvDhRendiN.WhlbIan.aRsyd.AndDEnOit.
# 6
# .IsmyldgilthlIezIedid.bhdymhstAdmedyWhzmoRDhnhlithlkhnsrndmyself.
# .HIsmyldgilthlIezHIAdhd.bhtymhsthdmityWhzmoRDhnhlithlkhnsrndmyself.
# 8
# .ykAnAtHOpDhtDIzpEjizWilbIolthgeDrfRIfrmhnakrnhzhnzAndeRrz.
# .ykAnatHOpDhtDIzpEjizWhlbIolthgeDrfRIfrmhnAkRhnizhmzAndeRrz.
# 7
# .ytukkWythfensItUHim.Wy.
# .ytuk.kWythfAnsItUHim.Wy.
# 2
# .Dhneksminht.SIWhzinDislIzoRmz.
# .Dhneksminht.SIWhzinDislEdIzaRmz.
# 3
# .misWhdlIdidnatRekhlektHrselfssO.bhtWhzsOinRIAlhtI.inHaRpIshndceRhtIWrinstiNkdivrcUz.AkshdenskudnatinkRIsDem.
# .misWudlIdidnatRekhlektHrselfsO.bhtWhzsOinRIAlhtI.inHrpIshndceRitIWrinstiNktivrcUz.AkshdhntkudnatinkRIsDem.
# 8
# .kladIhtWudnatan.enIhkwnt.hlwHimtUhkhmpnIr.AndTANkiNHimfrHiz.ofrzezWeleSIkulhd.tukklIvhvHimvintiRz.
# .klodIhWudnatan.enIhkwnt.hlwHimtUhkhmphnIHr.AndTANkiNHimfrHiz.ofrzezWelezSIkud.tuklIvhvHimintiRz.
# 9
# .?UdOmIntisEHIzgOiNthflodkrklhn.
# .?UdOntmIntisEHIzgOiNtiflagkrklhnd.
# 6
# .AndDEinkhnsisthnWumhnfelhpanHizbhtnIbRestWIpinkOppIhslIp.
# .AndDIinkhnsisthntWumhnfelhpanHizbhthnIbRestWIpiNkOp?hslI.
# 7
# .DEHalikhnbenth.hlzhndIOkhnfIldz.AAnd.bIiNtRItidWiTgREtfylhnsAndkUltIpyDiskatiSghvrmet.WeRDhnWhnsthgaRnstriNOsREnz.
# .DEHeldkhnvenikhlzinDIOphnfIldz.And.bIiNtRItidWiTgREtvyhlhnsAndkRUltIbyDhskatiSghvrmhnt.moRDhnWhnstukaRmzdriNDOzREnz.
# 26
# .RinkaRnEShnAndDhkanvrshspiRidz.
# .RIinkaRnEShnhndDhkanvrshvspiRits.
# 5
# .yluktAthtpRIklOs.hndysedgREt.ghd.
# .yluktAtitpRitIklOs.hndysedgREt.gad.
# 4
# .DisOphniNglukfr.olDhWrld.bykhmwDhvHel.inDhWrdzhvDIydtenrhntk?uRhthntpRIcrz.HUtrndhWEfrmitWiTHoR.
# .DisOphniNluktfr.olDhWrld.lykhmwThvHel.inDhWrdzhvDI.ytinrhntp?uRhthnpRIcrz.HUtrndhWEfrmitWiTHoRr.
# 10
# .ykudnatHelpsmyliNtisIUmluksObEginHizlithlHoRz.HizlonlegnwnDenthciNDhgRwnddmEdimluklykhsiksputHidsentaR.
# .ykudnatHelpsmyliNtisIimluksObiganHizlithlHoRs.HizloNlegznwhndDenthciNDhgRwndmEdHimluklykhsiksfutidsentoR.
# 13
# .bhtHIlukbAkhtrRhlsthn.DhgEDhvolzonDhb?Uthfhl.WizRilhfekShn.
# .bhtHIluktbAkAtcaRhlsthn.DhgEDhvalhthlhndDhb?Uthfhl.WiTRIlhfekShn.
# 13
# .WiThSwt.DhbYstASpElmelthmIkDhpAktRIn.AndfaliNAndbHyndDhslOWidiNbrz.riStDhmonWiTdrvhsifSwshnshdRIRIzwniNkslepsanDhAnhmhlzlyks.
# .WiThSwt.DhbYzdAStpelmelthmItDhpAktREn.AndfaliNinbiHyndDhslOmUviNbrOz.rjdDhmon.WiTdrisivSwtshndshndRIRIswndiNslApsonDhAnhmhlzflANks.
# 31
# .WYynathlw?oRsithlvrtoftsthlhgoRIEt.AndhnnatcROlmAnr.
# .Wynathlw?oRsilvrthftsthlhgZrIht.inhnAcrhlmAnr.
# 14
# .bhtHIRDIOnlITiNDhthkeRdthHrRWhztistaphndlukinWhnhvDhSapsthDHISudAskHrWeSIWhzlukiNAt.
# .bhtHIRDIOnlITiNDhthkrdthHrWhzthstaphndlukinWhnhvDhSapstilHISudAskHrWhtSIWhzlukiNAt.
# 8
# .HIHrAzWelOzinhnhmbrhvhDrplEsiz.WhnkhnWelhpRISIHAtDhkhlOkWIOldhfhneShnhvkAvrE.
# .HIRAzWelezinhnhmbrhvhDrplEshz.WhnkhnWelhpRISIEtDhkhlOkWIhldefhniShnhvkAbrE.
# 10
# .DhkAlhs.bhtikhtivlIvhpashl.smyldbEglIWhDizglUdlips.izkEstimUnfEsdRUpt.hvrDhWEthvmelhnkalIhsent.
# .mykelis.DhtikhthvlIvhpashl.smyldvEglIWiDHizglUdlips.HizpEstImUnfEsdRUpt.hndrDhWEthvmelhnkalIhsent.
# 14
# .AndSIsooDIhDrbrdtRpiNhbwtAndtWitrinHwplhslI.
# .AndSIsoDIhDrbrdzHapiNhbwtAndtWitriNHelplhslI.
# 7
# .myfRendWiTmenIhDrz.WhzbIiNkeRIdwt.tidyolsWeR.
# .myfRend.WiTmenIhDrz.WhzbIiNkeRIdwt.thdyelsWeR.
# 3
# .WhzHizmyndWandriNinthshmhDrtREnhvsot.
# .WhzHizmyndWandriNinthshmhDrtREn.hvTot.
# .HIgEvTANksfoRaRfUdhndkhmfrt.hndpREdfrDhpURAndesthtUtingREtsitIz.HWeRDhstRhghlfrlyfWhzHaRdrDhnitWhzHIRWiThs.
# 14
# .duiN?okShnHIWenthbwtWiDHizHedwhnhnevrlifthdHizyz.
# .duRiNDIakShnHIWenthbwtWiDHizHedwnhndnevrliftidHizyz.
# 7
# .AndgudfETHwevr.HIHiznatshfiShtlIimAjhnhti.thflAtrHimselfWiTDhslythztHOphvDiskynd.
# .ingudfETHwevr.HIiznatshfiShntlIimAjhnhtiv.thflAtrHimselfWiTDhslythstHOphvDiskynd.
# 6
# .itWhzhndrshcospiShsDrkhmstAnsizDAtSIstytidwtDismoRniNthlukfrWrk.
# .itWhzhndrshcaspiShsrkhmstAnsizDAtSIstaRthdwtDismoRniNthlukfrWrk.
# 5
# .HIcRAbhldOvrmenIlithldItelT.hnplaktprfhNtoRlIthevIbadI.
# .HItRhbhldOvrmenIlithldItElz.AndtoktprfhNktRhlIthevRIbadI.
# 12
# .nhbOTiNWhzhtRyfhlad.
# .DhHOlTiNWhzhtRyfhlad.
# 3
# .Azitiz.hndlesyhmhstEkhn.shmhvDhRendiN.WhlbIon.aRsyd.AndDEnOit.
# .Azitiz.hnlesyAmistEkhn.shmhvDhRendiN.WhlbIan.aRsyd.AndDEnOit.
# 4
# .IsmyldgilthlIezHIAdid.bhdymhstAdmedyWhzmoRDhnhlithlkhnsrndmyself.
# .HIsmyldgilthlIezHIAdhd.bhtymhsthdmityWhzmoRDhnhlithlkhnsrndmyself.
# 6
# .ykAnhtHOlpDhtDIzpEjizWhlbIolthgeDrfRIfrmynatkhnizhnzhndeRrz.
# .ykAnatHOpDhtDIzpEjizWhlbIolthgeDrfRIfrmhnAkRhnizhmzAndeRrz.
# 8
# .ytukhkWythfensitUHimWy.
# .ytuk.kWythfAnsItUHim.Wy.
# 4
# .Dhnneksminit.SIWhzinDislEzaRmz.
# .Dhneksminht.SIWhzinDislEdIzaRmz.
# 4
# .misWhtlIdidnatRekhlektHrselfsO.bhtWhzsOinRIAlhtI.inHapIshndceRhtIWrinsthndivrcUz.AkshthnzkudnatinkRIsDem.
# .misWudlIdidnatRekhlektHrselfsO.bhtWhzsOinRIAlhtI.inHrpIshndceRitIWrinstiNktivrcUz.AkshdhntkudnatinkRIsDem.
# 10
# .kladIitWudnatan.enIhkwnt.hlwHimtUhkhphnIHr.AndTiNkiNHimfrHiz.afrzezWeleSIkuud.tuklIvhvHimintiRz.
# .klodIhWudnatan.enIhkwnt.hlwHimtUhkhmphnIHr.AndTANkiNHimfrHiz.ofrzezWelezSIkud.tuklIvhvHimintiRz.
# 8
# .?UdOmINtisEHIzgOiNthflodkrklhn.
# .?UdOntmIntisEHIzgOiNtiflagkrklhnd.
# 7
# .hndDEinkhnsisthnoRmhnfelhpanHizbhtmIbRestWIpinkOpIhslIp.
# .AndDIinkhnsisthntWumhnfelhpanHizbhthnIbRestWIpiNkOp?hslI.
# 10
# .DEHAlitkhnbenthkOlzhnIOkhnfIldz.And.bIiNtRItidWiTgREtfyhlhntsinkUltIgWyDhskRatiSkhvrt.WrDhnWhnsthkWaRnstuRiNnOsREnz.
# .DEHeldkhnvenikhlzinDIOphnfIldz.And.bIiNtRItidWiTgREtvyhlhnsAndkRUltIbyDhskatiSghvrmhnt.moRDhnWhnstukaRmzdriNDOzREnz.
# 34
# .WInkaRnEShnhnDhkaNvrshspiRhts.
# .RIinkaRnEShnhndDhkanvrshvspiRits.
# 6
# .yluktAthtpRIklOs.hndysedgREt.gad.
# .yluktAtitpRitIklOs.hndysedgREt.gad.
# 3
# .DisOphniNlukfr.olDhWrld.lykhmwThvHil.inDhWrdzhvDIytenrhntp?uRhthnpRIcrz.HUtrndhWEfrmitWiTHoR.
# .DisOphniNluktfr.olDhWrld.lykhmwThvHel.inDhWrdzhvDI.ytinrhntp?uRhthnpRIcrz.HUtrndhWEfrmitWiTHoRr.
# 5
# .ykudnatHelpsmyliNtismluksibEgonHizlithlWoRs.HizloNlegnwhndDenthciNDhgRwndmEdHimluklykhsikslitidsentaR.
# .ykudnatHelpsmyliNtisIimluksObiganHizlithlHoRs.HizloNlegznwhndDenthciNDhgRwndmEdHimluklykhsiksfutidsentoR.
# 10
# .bhtHIlukbAkkAtrRhlsthn.DhgEDhvolzonDhb?Uthfhl.WiTRIlhfekShn.
# .bhtHIluktbAkAtcaRhlsthn.DhgEDhvalhthlhndDhb?Uthfhl.WiTRIlhfekShn.
# 11
# .WiThSwt.DhbYstAcpelmElthmIkDhpektRyt.AndfaliNHAndbiHyndDhslOlidiNbrz.rSDhlon.WiTtrvrzikSwtshndshdRIRIvwndiNsleptsanDhAnhmhlflyks.
# .WiThSwt.DhbYzdAStpelmelthmItDhpAktREn.AndfaliNinbiHyndDhslOmUviNbrOz.rjdDhmon.WiTdrisivSwtshndshndRIRIswndiNslApsonDhAnhmhlzflANks.
# 32
# .WynatOlw?oRsithlvrtoftsthlhgjoRIEt.indhnnatcROlmAnr.
# .Wynathlw?oRsilvrthftsthlhgZrIht.inhnAcrhlmAnr.
# 14
# .bhtHIRDIOnlITiNDhthkrdthHrWhzthstaphndlukhnmhnhvDhSapsthHISudAskHrWhtSIWhzlukiNAt.
# .bhtHIRDIOnlITiNDhthkrdthHrWhzthstaphndlukinWhnhvDhSapstilHISudAskHrWhtSIWhzlukiNAt.
# 4
# .HIHrAzWelhzinhnhmbrhvhDrplEsiz.WhnkhnWelhpRISIHitDikhlOkWIldhfhniShnhvkAvrE.
# .HIRAzWelezinhnhmbrhvhDrplEshz.WhnkhnWelhpRISIEtDhkhlOkWIhldefhniShnhvkAbrE.
# 10
# .DhkAlhs.DhtikhtivlIvhpashl.smydvEglIWiDhzglUdlips.izpEstImUnfEstRUpt.hnrDhWEthvmelhnkalIhvsent.
# .mykelis.DhtikhthvlIvhpashl.smyldvEglIWiDHizglUdlips.HizpEstImUnfEsdRUpt.hndrDhWEthvmelhnkalIhsent.
# 12
# .AndSIsoolDIhDrbrtsHapiNhbwtintWitrinHwlplhslI.
# .AndSIsoDIhDrbrdzHapiNhbwtAndtWitriNHelplhslI.
# 8
# .myfRendWiTmenIhDrz.WhzbIiNkeRIdwt.thdyelsWeR.
# .myfRend.WiTmenIhDrz.WhzbIiNkeRIdwt.thdyelsWeR.
# 1
# .WhzHizmyndWandriNinthshmhDrtREnhvTot.
# .WhzHizmyndWandriNinthshmhDrtREn.hvTot.
atshfiShntlIimAjhnhtiv.thflAtrHimselfWiTDhslythstHOphvDiskynd.
# 6
# .itWhzhndrshcAspiShssrkhmstAnsizDAtSIztytidwtDismoniNthlukfrWrk.
# .itWhzhndrshcaspiShsrkhmstAnsizDAtSIstaRthdwtDismoRniNthlukfrWrk.
# 7
# .HIcRAbhldhvrmenIlhbeldItelz.AntoktpRrfhNtoRlIthevRIbadI.
# .HItRhbhldOvrmenIlithldItElz.AndtoktprfhNktRhlIthevRIbadI.
# 12
# .nhbOTiNWhzhtRyfhlad.
# .DhHOlTiNWhzhtRyfhlad.
# 3
# .Azitiz.hndlesyAmhstEkhn.shmhvDhRendiN.WhlbIon.aRsyd.AndDEnOit.
# .Azitiz.hnlesyAmistEkhn.shmhvDhRendiN.WhlbIan.aRsyd.AndDEnOit.
# 3
# .HIsmyldgilthlIezHIAdid.bhdymhstAdmedyWhzmoRDhnhlithlkhnsrndmyself.
# .HIsmyldgilthlIezHIAdhd.bhtymhsthdmityWhzmoRDhnhlithlkhnsrndmyself.
# 5
# .ykAnAtHOlpDhtDIzpEjizWhlDIolthgeDrfRIfrmhnakhnizhmzAndeRrz.
# .ykAnatHOpDhtDIzpEjizWhlbIolthgeDrfRIfrmhnAkRhnizhmzAndeRrz.
# 5
# .ytukhkWythfAnsItUHim.Wy.
# .ytuk.kWythfAnsItUHim.Wy.
# 1
# .Dhtneksmintht.SIWhzinDislEzaRmz.
# .Dhneksminht.SIWhzinDislEdIzaRmz.
# 4
# .misWudlIdidnatRekhlektHrselfsO.bhtWhzsOInRIAlhtI.inHahpIzhndceRhtIWrinstiNktdivrcUz.AkshdhnskudnatinkRIsDen.
# .misWudlIdidnatRekhlektHrselfsO.bhtWhzsOinRIAlhtI.inHrpIshndceRitIWrinstiNktivrcUz.AkshdhntkudnatinkRIsDem.
# 8
# .klodIhtWudnatanenIhkwnt.hlwHimtUhkhmphnIHr.AndTiNkiNHimfrHiz.ofrzezWelezSIkoRd.tuklIvhvHimintiRz.
# .klodIhWudnatan.enIhkwnt.hlwHimtUhkhmphnIHr.AndTANkiNHimfrHiz.ofrzezWelezSIkud.tuklIvhvHimintiRz.
# 5
# .?UdOnmInNtisEHIzgOiNthflobkrklhm.
# .?UdOntmIntisEHIzgOiNtiflagkrklhnd.
# 7
# .hndDIiNkhnsisthntWumhnfelhpanHizbhtnIbRestWIpiNkOpIhslI.
# .AndDIinkhnsisthntWumhnfelhpanHizbhthnIbRestWIpiNkOp?hslI.
# 4
# .DEHAlkhnbenthkhlzhnHIOkhnfIldz.And.bIiNtRItidWiTgREtfylhnsindkUltIWydiskatiSkhvrmht.WeDhnWhnsthkaRdztrRInOsRInz.
# .DEHeldkhnvenikhlzinDIOphnfIldz.And.bIiNtRItidWiTgREtvyhlhnsAndkRUltIbyDhskatiSghvrmhnt.moRDhnWhnstukaRmzdriNDOzREnz.
# 28
# .WIinkrRnEShnindDhkanvrshspiRits.
# .RIinkaRnEShnhndDhkanvrshvspiRits.
# 4
# .yluktAtAtpRIklOs.hndysedgRREt.gad.
# .yluktAtitpRitIklOs.hndysedgREt.gad.
# 4
# .DisephniNluktfr.olDhWrld.bykhmwDhvHel.inDhWrdzhvDIytenrhntp?uRhthnpRIcrz.HUtrndhWEfrmitWiTH
atshfiShntlIimAjhnhtiv.thflAtrHimselfWiTDhslythstHOphvDiskynd.
# 5
# .itWhzhndrshcAspiShsrkhmstAnsizDAtSIstytidwtDismoRniNthlukfrWrk.
# .itWhzhndrshcaspiShsrkhmstAnsizDAtSIstaRthdwtDismoRniNthlukfrWrk.
# 4
# .HIcRAbhldevrmenIlibeldItElT.AntoktprfhNktoRlIthevRIbadI.
# .HItRhbhldOvrmenIlithldItElz.AndtoktprfhNktRhlIthevRIbadI.
# 9
# .DhHOTiNWhzhtRyfhlad.
# .DhHOlTiNWhzhtRyfhlad.
# 1
# .Azitiz.hndlesyAmhstEkhn.shmhvDhRendiN.WilbIon.aRsyd.AndDEnOit.
# .Azitiz.hnlesyAmistEkhn.shmhvDhRendiN.WhlbIan.aRsyd.AndDEnOit.
# 4
# .HIsmyldgilthlIezHIAdid.bhdymhstAdmARdyWhzmoRDhnhlithlkhnsrndmyself.
# .HIsmyldgilthlIezHIAdhd.bhtymhsthdmityWhzmoRDhnhlithlkhnsrndmyself.
# 6
# .ykAnAtHOpDhtDIzpEjizWhlDIolthgeDrfRIfrmhnakRhnizhmzAndeRrz.
# .ykAnatHOpDhtDIzpEjizWhlbIolthgeDrfRIfrmhnAkRhnizhmzAndeRrz.
# 3
# .ytukhkWythvensItUHim.Wy.
# .ytuk.kWythfAnsItUHim.Wy.
# 3
# .Dhneksmintht.SIWhzinDislEdIzaRmz.
# .Dhneksminht.SIWhzinDislEdIzaRmz.
# 1
# .misWhdlIdidnatRekhlektHrselfsO.bhtWhzsOinRIAlhtI.inHaRhpIshndceRhtIWrinstiNkdivrcUz.AkshdhnskudnatinkRIsDem.
# .misWudlIdidnatRekhlektHrselfsO.bhtWhzsOinRIAlhtI.inHrpIshndceRitIWrinstiNktivrcUz.AkshdhntkudnatinkRIsDem.
# 7
# .kladIhtWudnatonenIhkwnt.hlwHimtUhkhmphnIHr.AndTiNkiNHimfrHiz.ofrzezWelezSIkoRd.tuklIvhvHimintiRz.
# .klodIhWudnatan.enIhkwnt.hlwHimtUhkhmphnIHr.AndTANkiNHimfrHiz.ofrzezWelezSIkud.tuklIvhvHimintiRz.
# 7
# .UdOnmIntisEHIzgOiNthflokrklhm.
# .?UdOntmIntisEHIzgOiNtiflagkrklhnd.
# 7
# .AndDIinkhnsisthntoRmhnfelhpanHizbhtmIbRestWIpiNkOpIhslI.
# .AndDIinkhnsisthntWumhnfelhpanHizbhthnIbRestWIpiNkOp?hslI.
# 5
# .DEHAlikhnvent.OlzinDIOphnfIldz.And.bIiNtRItidWiTgREtfylhntsinkUltIWyDiskatiSkhvrmht.WeRDhnWhnsthkaRnztrRiNnOsREnz.
# .DEHeldkhnvenikhlzinDIOphnfIldz.And.bIiNtRItidWiTgREtvyhlhnsAndkRUltIbyDhskatiSghvrmhnt.moRDhnWhnstukaRmzdriNDOzREnz.
# 23
# .WIinkrRnEShnhndDhkanvrshspiRhnts.
# .RIinkaRnEShnhndDhkanvrshvspiRits.
# 5
# .yluktAtAtpRIklOs.hndysedgREt.gad.
# .yluktAtitpRitIklOs.hndysedgREt.gad.
# 3
# .DisOphniNluktfr.olDhWrld.bykhmwThvHil.inDhWrdzhvDIytenrhntp?uRhthnpRIcrz.HUtrndhWEfrmitWiTHoR.
# .DisOphniNluktfr.olDhWrld.lykhmwThvHel.inDhWrdzhvDI.ytinrhntp?uRhthnpRIcrz.HUtrndhWEfrmitWiTHoRr.
# 5
# .ykudnatHelpsmyliNtisImluksilbiganHizlithlHoRs.HizloNlegnwhnDenthciNDhgRwndmEdHimluklykhsiksutitsentaR.
# .ykudnatHelpsmyliNtisIimluksObiganHizlithlHoRs.HizloNlegznwhndDenthciNDhgRwndmEdHimluklykhsiksfutidsentoR.
# 8
# .bhtHIlukbAkAtaRlsthn.DhtgEDhvolzonDhb?Uthfhl.WhzRilhfekShn.
# .bhtHIluktbAkAtcaRhlsthn.DhgEDhvalhthlhndDhb?Uthfhl.WiTRIlhfekShn.
# 14
# .WiDhSelt.DhbYstASpElmElthmItDhpektRE.AndfaliNHAndbiHyndDhslOmidiNbrz.rShmon.WiTthvizikSwtshndshdRIRIzwndiNslepsanDhAnhmhlzlyNks.
# .WiThSwt.DhbYzdAStpelmelthmItDhpAktREn.AndfaliNinbiHyndDhslOmUviNbrOz.rjdDhmon.WiTdrisivSwtshndshndRIRIswndiNslApsonDhAnhmhlzflANks.
# 30
# .Wynathlw?oRsithlvrthftsthlhgZoRIEt.inhnhcRhlmAnr.
# .Wynathlw?oRsilvrthftsthlhgZrIht.inhnAcrhlmAnr.
# 7
# .bhtHIRDIOnlITiNDhthkeRdthHeRWhzthstaphndlukinWhnhvDhSapstilHISudAskHrWySIWhzlukiNAt.
# .bhtHIRDIOnlITiNDhthkrdthHrWhzthstaphndlukinWhnhvDhSapstilHISudAskHrWhtSIWhzlukiNAt.
# 6
# .HIHrAzWelezhnhnhmbrhvhDrplEsiz.WhnkhnWelhpRISIitDhkhlOkWIOldefhniShnhvkAvrE.
# .HIRAzWelezinhnhmbrhvhDrplEshz.WhnkhnWelhpRISIEtDhkhlOkWIhldefhniShnhvkAbrE.
# 7
# .DhkAlhs.DhtikhdiblIvhpashl.smylndvEglIWhDHizglUdlips.izpEstImUnfEsdRUpt.hnrDhWEthvmelhnkhlIhsent.
# .mykelis.DhtikhthvlIvhpashl.smyldvEglIWiDHizglUdlips.HizpEstImUnfEsdRUpt.hndrDhWEthvmelhnkalIhsent.
# 12
# .AndSIsoolDIhDrbrtsHApiNhbwtAntWitrInHelplhslI.
# .AndSIsoDIhDrbrdzHapiNhbwtAndtWitriNHelplhslI.
# 8
# .myfRendWiTmenIhDrz.WhzbIiNkeRIdwt.tidyelsWeR.
# .myfRend.WiTmenIhDrz.WhzbIiNkeRIdwt.thdyelsWeR.
# 2
# .WhzHizmyndWandriNinthshmhDrtREn.hvTot.
# .WhzHizmyndWandriNinthshmhDrtREn.hvTot.
# 0
# .itWhzshmTiNteRbhltUitnhsDhsylhnt.AghnI.Dhm?UtdispeRhvhtHUztiRzsylhdIWOldanHizcIks.
# .itWhzshmTiNteRhbhltUWitnhsDhsylhnt.AghnI.Dhm?Ut.dispeRhv!HUztiRzsylhntlIROldwnHizcIks.
# 10
# .DhsekhnbiginzHIR.hnEnShl.DhTrdHIR.duRsoN.ynw.
# .DhsekhnbiginzHIR.AnEnjhl.DhTrdHIR.diRsoN.ynO.
# 4
# Average Lev Distance 18 8.001286449399657
# AVG VAL LOSS PER BATCH 0.4237379435751889
# AVG_loss 100 loss=0.250023
# AVG_loss 200 loss=0.246646
# AVG_loss 300 loss=0.247011
atshfiShntlIimAjhnhtiv.thflAtrHimselfWiTDhslythstHOphvDiskynd.
# 6
# .itWhzhndrshcospiShsrkhmstAnsizDAtSIstytidwtDismoRniNthlukfrWrk.
# .itWhzhndrshcaspiShsrkhmstAnsizDAtSIstaRthdwtDismoRniNthlukfrWrk.
# 4
# .HIcRAbhldevrmenIlibeldItElT.AndtoktprfhNktoRlIthevRIbadI.
# .HItRhbhldOvrmenIlithldItElz.AndtoktprfhNktRhlIthevRIbadI.
# 8
# .DhHOTiNWhzhtRyfhlad.
# .DhHOlTiNWhzhtRyfhlad.
# 1
# .Azitiz.hndlesyAmistEkhn.shmhvDhRendiN.WhlbIon.aRsyd.AndDEnOit.
# .Azitiz.hnlesyAmistEkhn.shmhvDhRendiN.WhlbIan.aRsyd.AndDEnOit.
# 2
# .HIsmyldgilthlIezHIAdid.bhtymhstAdmedyWhzmoRDhnhlithlkhnsrndmyself.
# .HIsmyldgilthlIezHIAdhd.bhtymhsthdmityWhzmoRDhnhlithlkhnsrndmyself.
# 4
# .ykAnAtHOpDhtDIzpEjizWhlbIolthgeDrfRIfrmhnakRhnizhmzAndeRrz.
# .ykAnatHOpDhtDIzpEjizWhlbIolthgeDrfRIfrmhnAkRhnizhmzAndeRrz.
# 2
# .ytukhkWythvensItUHimWy.
# .ytuk.kWythfAnsItUHim.Wy.
# 4
# .Dhneksmintht.SIWhzinDislEdIzaRmz.
# .Dhneksminht.SIWhzinDislEdIzaRmz.
# 1
# .misWudlIdidnatRekhlektHrselfsO.bhtWhzsOinRIAlhtI.inHahpIshndceRhtIWrinstiNkdivrcUz.AkshdhnskudnatinkRIsDem.
# .misWudlIdidnatRekhlektHrselfsO.bhtWhzsOinRIAlhtI.inHrpIshndceRitIWrinstiNktivrcUz.AkshdhntkudnatinkRIsDem.
# 5
# .kladIhtWudnatonenIhkwnt.hlwHimtUhkhmphnIHr.AndTiNkiNHimfrHiz.ofrzezWelezSIkod.tuklIvhvHimintiRz.
# .klodIhWudnatan.enIhkwnt.hlwHimtUhkhmphnIHr.AndTANkiNHimfrHiz.ofrzezWelezSIkud.tuklIvhvHimintiRz.
# 6
# .?UdOnmInNtisEHIzgOiNthflogkrklhm.
# .?UdOntmIntisEHIzgOiNtiflagkrklhnd.
# 6
# .AndDIinkhnsisthndtWumhnfelhpanHizbhtmIbRestWIpiNkOpIhslI.
# .AndDIinkhnsisthntWumhnfelhpanHizbhthnIbRestWIpiNkOp?hslI.
# 4
# .DEHAlhkhnventhbhlzinIOphnfIldz.And.bIiNtRItidWiTgREtfylhntsinkUltIbyDhskatiSkhvrmht.WeRDhnWhnsthgaRnstuRinOsREnz.
# .DEHeldkhnvenikhlzinDIOphnfIldz.And.bIiNtRItidWiTgREtvyhlhnsAndkRUltIbyDhskatiSghvrmhnt.moRDhnWhnstukaRmzdriNDOzREnz.
# 26
# .WIinkrRnEShnhnDhkanvrshspiRhnts.
# .RIinkaRnEShnhndDhkanvrshvspiRits.
# 6
# .yluktAtAtpRIklOs.hndysedgREt.gad.
# .yluktAtitpRitIklOs.hndysedgREt.gad.
# 3
# .DisOphniNluktfr.olDhWrld.lykhmwThvHil.inDhWrdzhvDIytenrhntp?uRhthnpRIcrz.HUtrndhWEfrmitWiTHoR.
# .DisOphniNluktfr.olDhWrld.lykhmwThvHel.inDhWrdzhvDI.ytinrhntp?uRhthnpRIcrz.HUtrndhWEfrmitWiTHoRr.
# 4
# .ykudnatHelpsmyliNtisImluksilbigonHizlithlHoRs.HizloNlegnwhnDenthciNDhgRwndmEdHimluklykhsikslutitsentaR.
# .ykudnatHelpsmyliNtisIimluksObiganHizlithlHoRs.HizloNlegznwhndDenthciNDhgRwndmEdHimluklykhsiksfutidsentoR.
# 9
# .bhtHIlukbAkAtaRlsthn.DhtgEDhvolzonDhb?Uthfhl.WhzRilhfekShn.
# .bhtHIluktbAkAtcaRhlsthn.DhgEDhvalhthlhndDhb?Uthfhl.WiTRIlhfekShn.
# 14
# .WiDhSelt.DhbYstASpElmElthmItDhpektREn.AndfaliNHAndbiHyndDhslOmUdiNbrz.rSmon.WiTthvezhkSwtshndshdRIRIzwndiNslepsonDhAnhmhlzlyNks.
# .WiThSwt.DhbYzdAStpelmelthmItDhpAktREn.AndfaliNinbiHyndDhslOmUviNbrOz.rjdDhmon.WiTdrisivSwtshndshndRIRIswndiNslApsonDhAnhmhlzflANks.
# 30
# .Wynathlw?oRsithlvrthftsthlhgZoRIEt.inhnhcRhlmAnr.
# .Wynathlw?oRsilvrthftsthlhgZrIht.inhnAcrhlmAnr.
# 7
# .bhtHIRDIOnlITiNDhthkeRdthHeRWhzthstaphndlukinWhnhvDhSapstilHISudAskHrWySIWhzlukiNAt.
# .bhtHIRDIOnlITiNDhthkrdthHrWhzthstaphndlukinWhnhvDhSapstilHISudAskHrWhtSIWhzlukiNAt.
# 6
# .HIHrAzWelezinhnhmbrhvhDrplEsiz.WhnkhnWelhpRISIitDhkhlOkWIOldefhniShnhvkAvrE.
# .HIRAzWelezinhnhmbrhvhDrplEshz.WhnkhnWelhpRISIEtDhkhlOkWIhldefhniShnhvkAbrE.
# 6
# .DhkAlhs.DhtikhdiblIvhpashl.smylnvAglIWhDHhzglUdlips.izpEstImUnfEsdRUpt.hnrDhWEthvmelhnkhlIhsent.
# .mykelis.DhtikhthvlIvhpashl.smyldvEglIWiDHizglUdlips.HizpEstImUnfEsdRUpt.hndrDhWEthvmelhnkalIhsent.
# 14
# .AndSIsoolDIhDrbrtsHApiNhbwtintWitrINHelplhslI.
# .AndSIsoDIhDrbrdzHapiNhbwtAndtWitriNHelplhslI.
# 8
# .myfRendWiTmenIhDrz.WhzbIiNkeRIdwt.tidyelsWeR.
# .myfRend.WiTmenIhDrz.WhzbIiNkeRIdwt.thdyelsWeR.
# 2
# .WhzHizmyndWandriNinthshmhDrtREn.hvTot.
# .WhzHizmyndWandriNinthshmhDrtREn.hvTot.
# 0
# .itWhzshmTiNteRbhltUitnhsDhsylhnt.AghnI.Dhm?UcdispeRhvhthHUztiRzsylhndlIROldanHizcIks.
# .itWhzshmTiNteRhbhltUWitnhsDhsylhnt.AghnI.Dhm?Ut.dispeRhv!HUztiRzsylhntlIROldwnHizcIks.
# 9
# .DhsekhnbiginzHIR.AndEnShl.DhTrdHIR.duRsoN.ynw.
# .DhsekhnbiginzHIR.AnEnjhl.DhTrdHIR.diRsoN.ynO.
# 4
# Average Lev Distance 21 7.884648370497427
# AVG VAL LOSS PER BATCH 0.4225424983211466
# AVG_loss 100 loss=0.228542
# AVG_loss 200 loss=0.230320
# AVG_loss 300 loss=0.231241
# Average Lev Distance 22 7.865351629502573
# AVG VAL LOSS PER BATCH 0.42040032228908025
# AVG_loss 100 loss=0.223227
# AVG_loss 200 loss=0.226619
# AVG_loss 300 loss=0.227356
# Average Lev Distance 23 7.856346483704974
# AVG VAL LOSS PER BATCH 0.42429080726327123
# AVG_loss 100 loss=0.221257
# AVG_loss 200 loss=0.219653
# AVG_loss 300 loss=0.224652
# .misthkWildrezDIhpashlhvmithlklAsiz.AndWiRglAdtWelkhmHizgasphl.
# .Azitiz.hnlesyAmistEkhn.shmhvDhRendiN.WhlbIan.aRsyd.AndDEnOit.
# 3
# .HIsmyldgilthlIezHIAdid.bhtymhstAdmedyWhzmoRDhnhlithlkhnsrndmyself.
# .HIsmyldgilthlIezHIAdhd.bhtymhsthdmityWhzmoRDhnhlithlkhnsrndmyself.
# 4
# .ykAnAtHOpDhtDIzpEjizWhlbIolthgeDrfRIfrmhnakRhnizhmzAndeRrz.
# .ykAnatHOpDhtDIzpEjizWhlbIolthgeDrfRIfrmhnAkRhnizhmzAndeRrz.
# 2
# .ytukhkWythvensItUHimWy.
# .ytuk.kWythfAnsItUHim.Wy.
# 4
# .Dhneksmintht.SIWhzinDislEzaRmz.
# .Dhneksminht.SIWhzinDislEdIzaRmz.
# 3
# .misWudhlIdidnatRAkhlektHrselfsO.bhtWhzsOinRIAlhtI.inHwhpIshndceRhtIWrinstiNkdivrcUz.AksedhnskudnatinkRIsDem.
# .misWudlIdidnatRekhlektHrselfsO.bhtWhzsOinRIAlhtI.inHrpIshndceRitIWrinstiNktivrcUz.AkshdhntkudnatinkRIsDem.
# 8
# .kladIhtWudnatonenIhkwnt.hlwHimtUhkhmphnIHr.AndTiNkiNHimfrHiz.ofrzezWelezSIkod.tuklIvhvHimintiRz.
# .klodIhWudnatan.enIhkwnt.hlwHimtUhkhmphnIHr.AndTANkiNHimfrHiz.ofrzezWelezSIkud.tuklIvhvHimintiRz.
# 6
# .?UdOnmIniNtisEHIzgOiNthflodkrklhm.
# .?UdOntmIntisEHIzgOiNtiflagkrklhnd.
# 8
# .AndDIinkhnsisthntWumhnfelhpanHizbhtmIbRestWIpiNkOpIhslI.
# .AndDIinkhnsisthntWumhnfelhpanHizbhthnIbRestWIpiNkOp?hslI.
# 3
# .DEHelikinvent.OlzinIOkhnfIldz.And.bIiNtRItidWiTgREtfylhntsinkUltIbyDiskatiSkhvrmhnt.WeRDhnWhnsthkaRnstrRiNnOsREnz.
# .DEHeldkhnvenikhlzinDIOphnfIldz.And.bIiNtRItidWiTgREtvyhlhnsAndkRUltIbyDhskatiSghvrmhnt.moRDhnWhnstukaRmzdriNDOzREnz.
# 24
# .WIinkrRnEShnhnDhkanvrshspiRhnts.
# .RIinkaRnEShnhndDhkanvrshvspiRits.
# 6
# .yluktDAtAtpRIklOs.hndysedgREt.gad.
# .yluktAtitpRitIklOs.hndysedgREt.gad.
# 4
# .DisOphniNluktfr.olDhWrld.lykhmwThvHil.inDhWrdzhvDIytenrhntp?uRhthnpRIcrz.HUtrndhWEfrmitWiTHaR.
# .DisOphniNluktfr.olDhWrld.lykhmwThvHel.inDhWrdzhvDI.ytinrhntp?uRhthnpRIcrz.HUtrndhWEfrmitWiTHoRr.
# 5
# .ykudnatHelpsmyliNtisIUmluksObEganHizlithlHoRs.HizloNlegnwhnDenthciNDhgRwnddmEdHimluklykhsikslutitsentaR.
# .ykudnatHelpsmyliNtisIimluksObiganHizlithlHoRs.HizloNlegznwhndDenthciNDhgRwndmEdHimluklykhsiksfutidsentoR.
# 8
# .bhtHIlukbAkAcaRlsthn.DhtgEDhvolzonDhb?Uthfhl.WhzRilhfekShn.
# .bhtHIluktbAkAtcaRhlsthn.DhgEDhvalhthlhndDhb?Uthfhl.WiTRIlhfekShn.
# 14
# .WiThSwlt.DhbYstASpElmElthmItDhpektREn.AndfaliNHinbiHyndDhslOmrDiNbrlz.HrSdmon.WiTthvezhkSwtshndshdRIRivwndiNslepsanDhAnhmhlzlyNks.
# .WiThSwt.DhbYzdAStpelmelthmItDhpAktREn.AndfaliNinbiHyndDhslOmUviNbrOz.rjdDhmon.WiTdrisivSwtshndshndRIRIswndiNslApsonDhAnhmhlzflANks.
# 29
# .Wynathlw?oRsithlvrtoftsthlhgZoRIEt.inhnhcRhlmAnr.
# .Wynathlw?oRsilvrthftsthlhgZrIht.inhnAcrhlmAnr.
# 8
# .bhtHIRDIOnlITiNDhthkeRdthHeRWhzthstaphndlukinWhnhvDhSapstilHISudAskHrWySIWhzlukiNAt.
# .bhtHIRDIOnlITiNDhthkrdthHrWhzthstaphndlukinWhnhvDhSapstilHISudAskHrWhtSIWhzlukiNAt.
# 6
# .HIHrAzWelezhnhnhmbrhvhDrplEsiz.WhnkhnWelhpRISIHitDhkhlOkWIldefhniShnhvkAvrRE.
# .HIRAzWelezinhnhmbrhvhDrplEshz.WhnkhnWelhpRISIEtDhkhlOkWIhldefhniShnhvkAbrE.
# 9
# .DhkAlhs.DhtikhtiblIvhpashl.smyldbEglIWhDHizglUdlips.izpEstImUnfEsdRUpt.hnhDhWEthvmelhnkalIhsent.
# .mykelis.DhtikhthvlIvhpashl.smyldvEglIWiDHizglUdlips.HizpEstImUnfEsdRUpt.hndrDhWEthvmelhnkalIhsent.
# 11
# .AndSIsoolDIhDrbrtsHApinhbwtAntWitrinHelplhslI.
# .AndSIsoDIhDrbrdzHapiNhbwtAndtWitriNHelplhslI.
# 8
# .myfRendWiTmenIhDrz.WhzbIiNkeRIdwt.thdyelsWeR.
# .myfRend.WiTmenIhDrz.WhzbIiNkeRIdwt.thdyelsWeR.
# 1
# .WhzHizmyndWandriNinthshmhDrtREnhvTot.
# .WhzHizmyndWandriNinthshmhDrtREn.hvTot.
# 1
# .itWhzshmTiNtebhltUitnhsDhsylhnt.AghnI.Dhm?UtdispeRhvWhthHUztiRzsylhndlIWOldanHizcIks.
# .itWhzshmTiNteRhbhltUWitnhsDhsylhnt.AghnI.Dhm?Ut.dispeRhv!HUztiRzsylhntlIROldwnHizcIks.
# 11
# .DhsekhnbiginzHIR.AnEnShl.DhTrdHIR.duRshN.ynw.
# .DhsekhnbiginzHIR.AnEnjhl.DhTrdHIR.diRsoN.ynO.
# 4
# Average Lev Distance 24 7.834048027444254
# AVG VAL LOSS PER BATCH 0.42763981464746836
# AVG_loss 100 loss=0.217853
# AVG_loss 200 loss=0.218238
# AVG_loss 300 loss=0.217355
# Average Lev Distance 25 7.792881646655232
# AVG VAL LOSS PER BATCH 0.42398406726282994
# AVG_loss 100 loss=0.212581
# AVG_loss 200 loss=0.213867
# AVG_loss 300 loss=0.213169
# Average Lev Distance 26 7.740994854202401
# AVG VAL LOSS PER BATCH 0.4225864023775668
# AVG_loss 100 loss=0.207997
# AVG_loss 200 loss=0.208721
# AVG_loss 300 loss=0.214399
# .misthkWildrizDIhpashlhvmithlklAsiz.AndWiRglAdtWelkhmHizgasphl.
# .mistrkWiltrizDIhpashlhvDhmidhlklAshz.hndWIrglAdtUWelkhmHizgasphl.
# 10
# .hWEzhvdispeRhWOldOtfrm.yROlg.RIinsenstit.AndnUvhvfistWyt.WhzHiz.
# .hWEvhvdispeROldwtfrm!.bRyhnsenstit.AndnUDhfifTpYnt.WhzHiz.
# 1
# .Azitiz.hndlesyAmistEkhn.shmhvDhRendiN.WhlbIon.aRsyd.AndDEnOit.
# .Azitiz.hnlesyAmistEkhn.shmhvDhRendiN.WhlbIan.aRsyd.AndDEnOit.
# 2
# .HIsmyldgilthlIezHIAdid.bhtymhstAdmedyWhzmoRDhnhlithlkhnsrndmyself.
# .HIsmyldgilthlIezHIAdhd.bhtymhsthdmityWhzmoRDhnhlithlkhnsrndmyself.
# 4
# .ykAnAtHOpDhtDIzpEjizWhlbIolthgeDrfRIfrmhnakRhnizhmzAndeRrz.
# .ykAnatHOpDhtDIzpEjizWhlbIolthgeDrfRIfrmhnAkRhnizhmzAndeRrz.
# 2
# .ytukhkWythfensItUHimWy.
# .ytuk.kWythfAnsItUHim.Wy.
# 3
# .Dhneksmintht.SIWhzinDislEdIzaRmz.
# .Dhneksminht.SIWhzinDislEdIzaRmz.
# 1
# .misWudlIdidnatRAkhlektHrselfsO.bhtWhzsOinRIAlhtI.inHwhpIshndceRhtIWrinstiNktdivrcUz.AkshdhnskudnatinkRIsDem.
# .misWudlIdidnatRekhlektHrselfsO.bhtWhzsOinRIAlhtI.inHrpIshndceRitIWrinstiNktivrcUz.AkshdhntkudnatinkRIsDem.
# 6
# .kladIhtWudnatonenIhkwnt.hlwHimtUhkhmphnIHr.AndTiNkiNHimfrHiz.ofrzezWelezSIkod.tuklIvhvHimintiRz.
# .klodIhWudnatan.enIhkwnt.hlwHimtUhkhmphnIHr.AndTANkiNHimfrHiz.ofrzezWelezSIkud.tuklIvhvHimintiRz.
# 6
# .?UdOnmIniNtisEHIzgOiNthflokrklhm.
# .?UdOntmIntisEHIzgOiNtiflagkrklhnd.
# 8
# .AndDIinkhnsisthntWumhnfelhpanHizbhtmIbRestWIpiNkOpIhslI.
# .AndDIinkhnsisthntWumhnfelhpanHizbhthnIbRestWIpiNkOp?hslI.
# 3
# .DEHAlikhnventh.OlzinDIOphnfIldz.And.bIiNtRItidWiTgREtfylhntsinkUltIbyDiskatiSkhvrmhnt.WeRDhnWhnsthkaRnstuRiNnOsREnz.
# .DEHeldkhnvenikhlzinDIOphnfIldz.And.bIiNtRItidWiTgREtvyhlhnsAndkRUltIbyDhskatiSghvrmhnt.moRDhnWhnstukaRmzdriNDOzREnz.
# 24
# .WIinkrRnEShnhndDhkanvrshspiRints.
# .RIinkaRnEShnhndDhkanvrshvspiRits.
# 4
# .yluktDAtitpRIklOs.hndysedgREt.gad.
# .yluktAtitpRitIklOs.hndysedgREt.gad.
# 3
# .DisOphniNlukfr.olDhWrld.lykhmwThvHil.inDhWrdzhvDIytenrhntp?uRhthnpRIcrz.HUtrndhWEfrmitWiTHoR.
# .DisOphniNluktfr.olDhWrld.lykhmwThvHel.inDhWrdzhvDI.ytinrhntp?uRhthnpRIcrz.HUtrndhWEfrmitWiTHoRr.
# 5
# .ykudnatHelpsmyliNtisIUmluksObEganHizlithlHoRs.HizloNlegnwhndDenthciNDhgRwnddmEdHimluklykhsiksfutidsentaR.
# .ykudnatHelpsmyliNtisIimluksObiganHizlithlHoRs.HizloNlegznwhndDenthciNDhgRwndmEdHimluklykhsiksfutidsentoR.
# 5
# .bhtHIlukbAkAtaRlsthn.DhtgEDhvolzonDhb?Uthfhl.WizRIlhfekShn.
# .bhtHIluktbAkAtcaRhlsthn.DhgEDhvalhthlhndDhb?Uthfhl.WiTRIlhfekShn.
# 12
# .WiThSwlt.DhbYstASpElmElthmItDhpektREn.AndfaliNHindbiHyndDhslOmrliNbrlz.HrSmon.WiTthezhkSwtshndshdRigRizwndiNslepsanDhAnhmhlzlyNks.
# .WiThSwt.DhbYzdAStpelmelthmItDhpAktREn.AndfaliNinbiHyndDhslOmUviNbrOz.rjdDhmon.WiTdrisivSwtshndshndRIRIswndiNslApsonDhAnhmhlzflANks.
# 32
# .Wynathlw?oRsithlvrtofsthlhgZoRIEt.inhnhcRhlmAnr.
# .Wynathlw?oRsilvrthftsthlhgZrIht.inhnAcrhlmAnr.
# 9
# .bhtHIRDIOnlITiNDhthkeRdthHeRWhzthstaphndlukinWhnhvDhSapstilHISudAskHrWySIWhzlukiNAt.
# .bhtHIRDIOnlITiNDhthkrdthHrWhzthstaphndlukinWhnhvDhSapstilHISudAskHrWhtSIWhzlukiNAt.
# 6
# .HIHrAzWelezhnhnhmbrhvhDrplEsiz.WhnkhnWelhpRISIHitDhkhlOkWIldefhniShnhvkAvrRE.
# .HIRAzWelezinhnhmbrhvhDrplEshz.WhnkhnWelhpRISIEtDhkhlOkWIhldefhniShnhvkAbrE.
# 9
# .DhkAlhs.DhtikhtiblIvhpashl.smylnbEglIWhDHizglUdlips.izpEstImUnfEsdRUpthnrDhWEthvmelhnkalIhsent.
# .mykelis.DhtikhthvlIvhpashl.smyldvEglIWiDHizglUdlips.HizpEstImUnfEsdRUpt.hndrDhWEthvmelhnkalIhsent.
# 12
# .AndSIsoolDIhDrbrtsHApiNhbwtAntWitrinHelplhslI.
# .AndSIsoDIhDrbrdzHapiNhbwtAndtWitriNHelplhslI.
# 7
# .myfRendWiTmenIhDrz.WhzbIiNkeRIdwt.thdyelsWeR.
# .myfRend.WiTmenIhDrz.WhzbIiNkeRIdwt.thdyelsWeR.
# 1
# .WhzHizmyndWandriNinthshmhDrtREnhvTot.
# .WhzHizmyndWandriNinthshmhDrtREn.hvTot.
# 1
# .itWhzshmTiNtebhltUitnhsDhsylhnt.AghnI.Dhm?UcdispeRhvWhtEHUztiRzsylhndlIWOldanHizcIks.
# .itWhzshmTiNteRhbhltUWitnhsDhsylhnt.AghnI.Dhm?Ut.dispeRhv!HUztiRzsylhntlIROldwnHizcIks.
# 12
# .DhsekhnbiginzHIR.AnEnShl.DhTrdHIR.duRshN.ynw.
# .DhsekhnbiginzHIR.AnEnjhl.DhTrdHIR.diRsoN.ynO.
# 4
# Average Lev Distance 27 7.779159519725558
# AVG VAL LOSS PER BATCH 0.4260690151839643
# AVG_loss 100 loss=0.202936
# AVG_loss 200 loss=0.208316
# AVG_loss 300 loss=0.208654
# Average Lev Distance 28 7.7397084048027445
# AVG VAL LOSS PER BATCH 0.4261687510722392
# AVG_loss 100 loss=0.201805
# AVG_loss 200 loss=0.203343
# AVG_loss 300 loss=0.203904
# Average Lev Distance 29 7.732847341337908
# AVG VAL LOSS PER BATCH 0.42723275680799744
